# %%
# Import the relevant classes.
from Chapter2.CreateDataset import CreateDataset
from util.VisualizeDataset import VisualizeDataset
from util import util
import pandas as pd

# %%
base_dir = './datasets/dataframes/'

# %%
df_walking = pd.read_pickle(base_dir + 'df_walking_gran_250.pkl')

# %%
df_walking.head()
# Out:
#                          Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# Time (s)
# 1970-01-01 00:00:00.000               -0.405317                2.483034
# 1970-01-01 00:00:00.250               -0.856193                2.997881
# 1970-01-01 00:00:00.500               -1.295935                3.048065
# 1970-01-01 00:00:00.750               -0.481996                2.723746
# 1970-01-01 00:00:01.000                0.037427                3.717198
#
#                          Acceleration z (m/s^2)  Gyroscope x (rad/s)  \
# Time (s)
# 1970-01-01 00:00:00.000                9.345501                  NaN
# 1970-01-01 00:00:00.250                8.358164             0.147191
# 1970-01-01 00:00:00.500               10.177966            -0.087631
# 1970-01-01 00:00:00.750                7.952019             0.122121
# 1970-01-01 00:00:01.000                9.854835            -0.137473
#
#                          Gyroscope y (rad/s)  Gyroscope z (rad/s)  \
# Time (s)
# ...

# %%
df_crowdsignals = pd.read_csv('intermediate_datafiles/chapter2_result.csv')

# %%
df_crowdsignals
# Out:
#                           Unnamed: 0  acc_phone_x  acc_phone_y  acc_phone_z  \
# 0      2016-02-08 18:28:25.656222395    -0.090431     0.164098     9.631765
# 1      2016-02-08 18:28:25.906222395    -0.097600     0.167640     9.631740
# 2      2016-02-08 18:28:26.156222395    -0.089120     0.167520     9.637300
# 3      2016-02-08 18:28:26.406222395    -0.090135     0.166019     9.632538
# 4      2016-02-08 18:28:26.656222395    -0.090608     0.167686     9.630078
# ...                              ...          ...          ...          ...
# 31833  2016-02-08 20:41:03.906222395    -0.163020     0.184061     9.609571
# 31834  2016-02-08 20:41:04.156222395    -0.162686     0.185196     9.611863
# 31835  2016-02-08 20:41:04.406222395    -0.159980     0.186800     9.615020
# 31836  2016-02-08 20:41:04.656222395    -0.158882     0.184333     9.613510
# 31837  2016-02-08 20:41:04.906222395    -0.164737     0.182632     9.623053
#
# ...
